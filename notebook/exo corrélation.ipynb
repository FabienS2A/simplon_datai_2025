# %% [markdown]
# Exercices pratique
# Measurer la corrélation entre :
# two random set

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x = np.random.randint(0,100,1000)
y = np.random.randint(0,100,1000)


plt.scatter(x,y)
pearson_corr = np.corrcoef(x,y)

print(pearson_corr)
plt.show()
# Out:
# [[ 1.         -0.04929206]
#  [-0.04929206  1.        ]]

# %% [markdown]
# bewtween a cosinus and a sinus variables

# %%
x = np.linspace(0, 10, 100)
y1 = np.sin(x)
y2 = np.cos(x)



pearson_corr = np.corrcoef(y1,y2)
plt.plot(x, y1)
plt.plot(x, y2)
plt.show()
print(pearson_corr)
plt.show()
# Out:
# [[1.         0.05486669]
#  [0.05486669 1.        ]]

# %% [markdown]
# two gaussian distributed data with different mean and variance (play with the parameters)

# %%
x = np.random.normal(loc=0,size=1000)
y = np.random.normal(loc=4,size=1000)



pearson_corr = np.corrcoef(x,y)

print(pearson_corr)
plt.hist(x,(20))
plt.hist(y,(20))
# Out:
# [[ 1.         -0.04113416]
#  [-0.04113416  1.        ]]
# (array([  3.,   5.,  10.,  21.,  27.,  69., 105., 139., 143., 129., 118.,
#          99.,  55.,  38.,  15.,  17.,   6.,   0.,   0.,   1.]),
#  array([0.73928925, 1.10465902, 1.47002879, 1.83539856, 2.20076833,
#         2.5661381 , 2.93150787, 3.29687764, 3.66224741, 4.02761718,
#         4.39298695, 4.75835672, 5.12372649, 5.48909626, 5.85446603,
#         6.2198358 , 6.58520557, 6.95057534, 7.31594511, 7.68131488,
#         8.04668465]),
#  <BarContainer object of 20 artists>)

# %%
x = np.random.normal(loc=0,scale=1,size=1000)
y = np.random.normal(loc=20,scale=3,size=1000)



pearson_corr = np.corrcoef(x,y)

print(pearson_corr)
plt.hist(x,(20))
plt.hist(y,(20))
# Out:
# [[1.         0.03161902]
#  [0.03161902 1.        ]]
# (array([ 11.,  14.,  20.,  34.,  76.,  75., 115., 102., 120., 134., 108.,
#          60.,  54.,  31.,  22.,  13.,   9.,   0.,   1.,   1.]),
#  array([12.20384269, 13.1367932 , 14.06974372, 15.00269423, 15.93564475,
#         16.86859526, 17.80154577, 18.73449629, 19.6674468 , 20.60039732,
#         21.53334783, 22.46629834, 23.39924886, 24.33219937, 25.26514989,
#         26.1981004 , 27.13105091, 28.06400143, 28.99695194, 29.92990246,
#         30.86285297]),
#  <BarContainer object of 20 artists>)
